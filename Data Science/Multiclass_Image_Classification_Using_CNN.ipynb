# %% [markdown]
# ### **Multiclass Image Classification Using CNN**

# %% [markdown]
# In this notebook I have shown how a simple CNN is implemented on a multiclass image classification problem. I have covered
#
# **1.** How to create a CNN Model and Train it.
#
# **2.** How to evaluate the model on test set using different classification metrics.
#
# **3.** How to visualize the images present in the training and test set.

# %% [markdown]
# ### **1. Import the Required Libraries**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import cv2
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, BatchNormalization, Conv2D, Dense, Dropout, Flatten, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# %% [markdown]
# ### **2. Load the Image Training and Validation Datasets**

# %% [markdown]
# #### **i. Get the Image Dataset Paths**

# %%
train_dataset_path = '/kaggle/input/intel-image-classification/seg_train/seg_train/'
validation_dataset_path = '/kaggle/input/intel-image-classification/seg_test/seg_test/'

# %% [markdown]
# #### **ii. Load Image Datasets and Apply Augmentations**

# %% [markdown]
# Since the images present in the datasets are 150x150px in size, the image height and width are taken as 150, 150 respectively. The batch size value can be changed if required.

# %%
IMG_WIDTH = 150
IMG_HEIGHT = 150
BATCH_SIZE = 32

# %% [markdown]
# Loading the training dataset and applying augmentations on it.

# %%
train_datagen = ImageDataGenerator(rescale=1.0/255,
                                  zoom_range=0.2,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  fill_mode='nearest')
train_generator = train_datagen.flow_from_directory(train_dataset_path,
                                                   target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                   batch_size=BATCH_SIZE,
                                                   class_mode='categorical',
                                                   shuffle=True)
# Out:
# Found 14034 images belonging to 6 classes.

# %% [markdown]
# Loading the validation dataset.

# %%
validation_datagen = ImageDataGenerator(rescale=1.0/255)
validation_generator = validation_datagen.flow_from_directory(validation_dataset_path,
                                                             target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                             batch_size=BATCH_SIZE,
                                                             class_mode='categorical',
                                                             shuffle=True)
# Out:
# Found 3000 images belonging to 6 classes.

# %% [markdown]
# #### **iii. Get the Label Mappings**

# %% [markdown]
# The labels dictionary is made in order to retrive the class names against the label indices used for training the model

# %%
labels = {value: key for key, value in train_generator.class_indices.items()}

print("Label Mappings for classes present in the training and validation datasets\n")
for key, value in labels.items():
    print(f"{key} : {value}")
# Out:
# Label Mappings for classes present in the training and validation datasets
#
# 0 : buildings
# 1 : forest
# 2 : glacier
# 3 : mountain
# 4 : sea
# 5 : street

# %% [markdown]
# ### **3. Plotting Sample Training Images**

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(15, 12))
idx = 0

for i in range(2):
    for j in range(5):
        label = labels[np.argmax(train_generator[0][1][idx])]
        ax[i, j].set_title(f"{label}")
        ax[i, j].imshow(train_generator[0][0][idx][:, :, :])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Sample Training Images", fontsize=21)
plt.show()

# %% [markdown]
# ### **4. Training a CNN Model**

# %% [markdown]
# Since the training dataset is ready let's create a simple CNN Model to train on the image datasets

# %% [markdown]
# #### **i. Create a CNN Model**

# %%
def create_model():
    model = Sequential([
        Conv2D(filters=128, kernel_size=(5, 5), padding='valid', input_shape=(IMG_WIDTH, IMG_HEIGHT, 3)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),

        Conv2D(filters=64, kernel_size=(3, 3), padding='valid', kernel_regularizer=l2(0.00005)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),

        Conv2D(filters=32, kernel_size=(3, 3), padding='valid', kernel_regularizer=l2(0.00005)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),

        Flatten(),

        Dense(units=256, activation='relu'),
        Dropout(0.5),
        Dense(units=6, activation='softmax')
    ])

    return model

# %%
cnn_model = create_model()

# %%
print(cnn_model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 146, 146, 128)     9728
# _________________________________________________________________
# activation (Activation)      (None, 146, 146, 128)     0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 73, 73, 128)       0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 73, 73, 128)       512
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 71, 71, 64)        73792
# _________________________________________________________________
# activation_1 (Activation)    (None, 71, 71, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 35, 35, 64)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 35, 35, 64)        256
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 33, 33, 32)        18464
# _________________________________________________________________
# activation_2 (Activation)    (None, 33, 33, 32)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 32)        128
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               2097408
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 1542
# =================================================================
# Total params: 2,201,830
# Trainable params: 2,201,382
# Non-trainable params: 448
# _________________________________________________________________
# None

# %% [markdown]
# #### **ii. Defining Callbacks**

# %% [markdown]
# A callback is an object that can perform actions at various stages of training (e.g. at the start or end of an epoch, before or after a single batch, etc)

# %% [markdown]
# #### **a. Reduce Learning Rate on Plateau**
#
# Is used to reduce the learning rate when a metric has stopped improving.

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=np.sqrt(0.1), patience=5)

# %% [markdown]
# #### **iii. Defining the Optimizer**

# %%
optimizer = Adam(learning_rate=0.001)

# %% [markdown]
# #### **iv. Compile the Model**

# %%
cnn_model.compile(optimizer=optimizer, loss=CategoricalCrossentropy(), metrics=['accuracy'])

# %% [markdown]
# #### **v. Training the Model**

# %%
history = cnn_model.fit(train_generator, epochs=50, validation_data=validation_generator,
                       verbose=2,
                       callbacks=[reduce_lr])
# Out:
# Epoch 1/50
# 439/439 - 161s - loss: 2.0901 - accuracy: 0.5002 - val_loss: 1.2521 - val_accuracy: 0.6000
# Epoch 2/50
# 439/439 - 83s - loss: 1.0809 - accuracy: 0.6156 - val_loss: 1.1029 - val_accuracy: 0.6287
# Epoch 3/50
# 439/439 - 83s - loss: 0.9243 - accuracy: 0.6651 - val_loss: 1.2017 - val_accuracy: 0.6270
# Epoch 4/50
# 439/439 - 83s - loss: 0.8334 - accuracy: 0.6999 - val_loss: 2.2388 - val_accuracy: 0.4853
# Epoch 5/50
# 439/439 - 84s - loss: 0.7735 - accuracy: 0.7225 - val_loss: 0.8992 - val_accuracy: 0.6623
# Epoch 6/50
# 439/439 - 83s - loss: 0.7459 - accuracy: 0.7321 - val_loss: 0.7352 - val_accuracy: 0.7530
# Epoch 7/50
# 439/439 - 83s - loss: 0.7061 - accuracy: 0.7530 - val_loss: 0.8692 - val_accuracy: 0.7067
# Epoch 8/50
# 439/439 - 83s - loss: 0.6888 - accuracy: 0.7599 - val_loss: 0.7742 - val_accuracy: 0.7473
# Epoch 9/50
# 439/439 - 83s - loss: 0.6652 - accuracy: 0.7693 - val_loss: 3.4069 - val_accuracy: 0.4660
# Epoch 10/50
# 439/439 - 83s - loss: 0.6371 - accuracy: 0.7743 - val_loss: 1.8003 - val_accuracy: 0.6140
# Epoch 11/50
# 439/439 - 83s - loss: 0.6185 - accuracy: 0.7861 - val_loss: 0.5749 - val_accuracy: 0.8143
# Epoch 12/50
# 439/439 - 82s - loss: 0.6016 - accuracy: 0.7978 - val_loss: 0.5287 - val_accuracy: 0.8307
# Epoch 13/50
# 439/439 - 82s - loss: 0.5815 - accuracy: 0.8002 - val_loss: 0.4776 - val_accuracy: 0.8397
# Epoch 14/50
# 439/439 - 82s - loss: 0.5586 - accuracy: 0.8047 - val_loss: 0.4769 - val_accuracy: 0.8467
# Epoch 15/50
# 439/439 - 83s - loss: 0.5514 - accuracy: 0.8115 - val_loss: 0.4874 - val_accuracy: 0.8357
# Epoch 16/50
# 439/439 - 84s - loss: 0.5477 - accuracy: 0.8131 - val_loss: 0.4165 - val_accuracy: 0.8600
# Epoch 17/50
# 439/439 - 83s - loss: 0.5482 - accuracy: 0.8138 - val_loss: 0.6286 - val_accuracy: 0.7990
# Epoch 18/50
# 439/439 - 82s - loss: 0.5224 - accuracy: 0.8239 - val_loss: 1.0530 - val_accuracy: 0.7023
# Epoch 19/50
# 439/439 - 83s - loss: 0.5268 - accuracy: 0.8214 - val_loss: 0.6012 - val_accuracy: 0.8117
# Epoch 20/50
# 439/439 - 83s - loss: 0.5069 - accuracy: 0.8278 - val_loss: 0.5790 - val_accuracy: 0.8100
# Epoch 21/50
# 439/439 - 83s - loss: 0.5102 - accuracy: 0.8266 - val_loss: 0.4891 - val_accuracy: 0.8400
# Epoch 22/50
# 439/439 - 82s - loss: 0.4484 - accuracy: 0.8469 - val_loss: 0.4090 - val_accuracy: 0.8687
# Epoch 23/50
# 439/439 - 83s - loss: 0.4163 - accuracy: 0.8604 - val_loss: 0.3562 - val_accuracy: 0.8793
# Epoch 24/50
# 439/439 - 82s - loss: 0.4097 - accuracy: 0.8621 - val_loss: 0.4466 - val_accuracy: 0.8543
# Epoch 25/50
# 439/439 - 84s - loss: 0.4105 - accuracy: 0.8632 - val_loss: 0.4123 - val_accuracy: 0.8590
# Epoch 26/50
# 439/439 - 82s - loss: 0.4038 - accuracy: 0.8625 - val_loss: 0.3968 - val_accuracy: 0.8700
# Epoch 27/50
# 439/439 - 83s - loss: 0.4010 - accuracy: 0.8650 - val_loss: 0.4016 - val_accuracy: 0.8657
# Epoch 28/50
# 439/439 - 83s - loss: 0.3963 - accuracy: 0.8648 - val_loss: 0.8413 - val_accuracy: 0.8000
# Epoch 29/50
# 439/439 - 84s - loss: 0.3734 - accuracy: 0.8765 - val_loss: 0.3439 - val_accuracy: 0.8860
# Epoch 30/50
# 439/439 - 82s - loss: 0.3663 - accuracy: 0.8771 - val_loss: 0.3419 - val_accuracy: 0.8933
# Epoch 31/50
# 439/439 - 83s - loss: 0.3555 - accuracy: 0.8802 - val_loss: 0.3347 - val_accuracy: 0.8923
# Epoch 32/50
# 439/439 - 83s - loss: 0.3522 - accuracy: 0.8824 - val_loss: 0.3309 - val_accuracy: 0.8917
# Epoch 33/50
# 439/439 - 83s - loss: 0.3486 - accuracy: 0.8842 - val_loss: 0.3536 - val_accuracy: 0.8867
# Epoch 34/50
# 439/439 - 83s - loss: 0.3537 - accuracy: 0.8817 - val_loss: 0.3181 - val_accuracy: 0.8950
# Epoch 35/50
# 439/439 - 82s - loss: 0.3422 - accuracy: 0.8839 - val_loss: 0.3350 - val_accuracy: 0.8893
# Epoch 36/50
# 439/439 - 83s - loss: 0.3383 - accuracy: 0.8832 - val_loss: 0.3282 - val_accuracy: 0.8933
# Epoch 37/50
# 439/439 - 83s - loss: 0.3503 - accuracy: 0.8824 - val_loss: 0.3487 - val_accuracy: 0.8873
# Epoch 38/50
# 439/439 - 84s - loss: 0.3484 - accuracy: 0.8846 - val_loss: 0.3329 - val_accuracy: 0.8923
# Epoch 39/50
# 439/439 - 82s - loss: 0.3433 - accuracy: 0.8814 - val_loss: 0.3226 - val_accuracy: 0.8973
# Epoch 40/50
# 439/439 - 84s - loss: 0.3330 - accuracy: 0.8852 - val_loss: 0.3269 - val_accuracy: 0.8927
# Epoch 41/50
# 439/439 - 82s - loss: 0.3316 - accuracy: 0.8913 - val_loss: 0.3311 - val_accuracy: 0.8933
# Epoch 42/50
# 439/439 - 83s - loss: 0.3278 - accuracy: 0.8880 - val_loss: 0.3231 - val_accuracy: 0.8940
# Epoch 43/50
# 439/439 - 82s - loss: 0.3260 - accuracy: 0.8898 - val_loss: 0.3290 - val_accuracy: 0.8923
# Epoch 44/50
# 439/439 - 83s - loss: 0.3326 - accuracy: 0.8871 - val_loss: 0.3454 - val_accuracy: 0.8907
# Epoch 45/50
# 439/439 - 82s - loss: 0.3242 - accuracy: 0.8897 - val_loss: 0.3324 - val_accuracy: 0.8920
# Epoch 46/50
# 439/439 - 83s - loss: 0.3225 - accuracy: 0.8906 - val_loss: 0.3260 - val_accuracy: 0.8940
# Epoch 47/50
# 439/439 - 83s - loss: 0.3178 - accuracy: 0.8914 - val_loss: 0.3212 - val_accuracy: 0.8930
# Epoch 48/50
# 439/439 - 83s - loss: 0.3267 - accuracy: 0.8897 - val_loss: 0.3326 - val_accuracy: 0.8920
# Epoch 49/50
# 439/439 - 83s - loss: 0.3273 - accuracy: 0.8878 - val_loss: 0.3283 - val_accuracy: 0.8940
# Epoch 50/50
# 439/439 - 83s - loss: 0.3181 - accuracy: 0.8920 - val_loss: 0.3279 - val_accuracy: 0.8943

# %% [markdown]
# ### **5. Plotting the Model Metrics**

# %% [markdown]
# #### **i. Plotting training and validation accuracy, loss and learning rate**

# %%
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']

learning_rate = history.history['lr']

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

ax[2].set_title('Learning Rate vs. Epochs')
ax[2].plot(learning_rate, 'o-', label='Learning Rate')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].legend(loc='best')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **6. Testing the Model on Test Set**

# %% [markdown]
# Testing the model on the validation dataset because a seperate dataset for testing is not available.

# %%
test_dataset = '/kaggle/input/intel-image-classification/seg_test/seg_test/'

# %%
test_datagen = ImageDataGenerator(rescale=1.0/255)

test_generator = test_datagen.flow_from_directory(test_dataset,
                                                 shuffle=False,
                                                 batch_size=BATCH_SIZE,
                                                 target_size = (IMG_WIDTH, IMG_HEIGHT),
                                                 class_mode='categorical')
# Out:
# Found 3000 images belonging to 6 classes.

# %% [markdown]
# ### **7. Model Prediction on the Test Dataset**

# %%
predictions = cnn_model.predict(test_generator)

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        predicted_label = labels[np.argmax(predictions[idx])]
        ax[i, j].set_title(f"{predicted_label}")
        ax[i, j].imshow(test_generator[0][0][idx])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Test Dataset Predictions", fontsize=20)
plt.show()

# %%
test_loss, test_accuracy = cnn_model.evaluate(test_generator, batch_size=BATCH_SIZE)
# Out:
# 94/94 [==============================] - 4s 46ms/step - loss: 0.3279 - accuracy: 0.8943

# %%
print(f"Test Loss:     {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Test Loss:     0.3279026746749878
# Test Accuracy: 0.8943333625793457

# %% [markdown]
# The test loss and test accuracy is the same as validation loss and validation accuracy at the last step since the testing and validation datasets are same.

# %% [markdown]
# ### **8. Plotting the Classification Metrics**

# %% [markdown]
# ### **i. Confusion Matrix**

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes

# %%
cf_mtx = confusion_matrix(y_true, y_pred)

group_counts = ["{0:0.0f}".format(value) for value in cf_mtx.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_mtx.flatten()/np.sum(cf_mtx)]
box_labels = [f"{v1}\n({v2})" for v1, v2 in zip(group_counts, group_percentages)]
box_labels = np.asarray(box_labels).reshape(6, 6)

plt.figure(figsize = (12, 10))
sns.heatmap(cf_mtx, xticklabels=labels.values(), yticklabels=labels.values(),
           cmap="YlGnBu", fmt="", annot=box_labels)
plt.xlabel('Predicted Classes')
plt.ylabel('True Classes')
plt.show()

# %%
print(classification_report(y_true, y_pred, target_names=labels.values()))
# Out:
#               precision    recall  f1-score   support
#
#    buildings       0.84      0.91      0.88       437
#       forest       0.96      0.98      0.97       474
#      glacier       0.87      0.84      0.86       553
#     mountain       0.87      0.83      0.85       525
#          sea       0.91      0.93      0.92       510
#       street       0.91      0.89      0.90       501
#
#     accuracy                           0.89      3000
#    macro avg       0.89      0.90      0.90      3000
# weighted avg       0.89      0.89      0.89      3000

# %% [markdown]
# ### **9. Wrong Predictions**
#
# Let's see where the model has given wrong predictions and what were the actual predictions on those images.

# %%
errors = (y_true - y_pred != 0)
y_true_errors = y_true[errors]
y_pred_errors = y_pred[errors]

# %%
test_images = test_generator.filenames
test_img = np.asarray(test_images)[errors]

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        idx = np.random.randint(0, len(test_img))
        true_index = y_true_errors[idx]
        true_label = labels[true_index]
        predicted_index = y_pred_errors[idx]
        predicted_label = labels[predicted_index]
        ax[i, j].set_title(f"True Label: {true_label} \n Predicted Label: {predicted_label}")
        img_path = os.path.join(test_dataset, test_img[idx])
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        ax[i, j].imshow(img)
        ax[i, j].axis("off")

plt.tight_layout()
plt.suptitle('Wrong Predictions made on test set', fontsize=20)
plt.show()
